# %% [markdown]
# # ਐਜ਼ਰ ਏਆਈ ਏਜੰਟਸ ਮਾਡਲ ਕਾਂਟੈਕਸਟ ਪ੍ਰੋਟੋਕੋਲ (MCP) ਸਹਾਇਤਾ ਨਾਲ
#
# ਇਹ ਨੋਟਬੁੱਕ ਦਿਖਾਉਂਦੀ ਹੈ ਕਿ ਕਿਵੇਂ ਐਜ਼ਰ ਏਆਈ ਏਜੰਟਸ ਨੂੰ ਮਾਡਲ ਕਾਂਟੈਕਸਟ ਪ੍ਰੋਟੋਕੋਲ (MCP) ਟੂਲਜ਼ ਨਾਲ ਵਰਤ ਕੇ ਇੱਕ ਸਮਰੱਥ ਏਜੰਟ ਬਣਾਇਆ ਜਾ ਸਕਦਾ ਹੈ ਜੋ ਵਧੇਰੇ ਸਮਰੱਥਾਵਾਂ ਲਈ ਬਾਹਰੀ MCP ਸਰਵਰਾਂ ਦਾ ਲਾਭ ਲੈ ਸਕੇ।

# %% [markdown]
# ## ਲੋੜੀਂਦੇ NuGet ਪੈਕੇਜ ਇੰਸਟਾਲ ਕਰੋ
#
# ਸਭ ਤੋਂ ਪਹਿਲਾਂ, ਸਾਨੂੰ Azure AI Agents Persistent ਪੈਕੇਜ ਇੰਸਟਾਲ ਕਰਨ ਦੀ ਲੋੜ ਹੈ ਜੋ Azure AI Agents ਨਾਲ ਕੰਮ ਕਰਨ ਲਈ ਮੁੱਖ ਕਾਰਗੁਜ਼ਾਰੀ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ।

# %% [markdown]
# ## ਕੀਲੈਸ ਪ੍ਰਮਾਣਿਕਤਾ ਦੇ ਫਾਇਦੇ
#
# ਇਹ ਨੋਟਬੁੱਕ **ਕੀਲੈਸ ਪ੍ਰਮਾਣਿਕਤਾ** ਨੂੰ ਦਰਸਾਉਂਦੀ ਹੈ, ਜੋ ਕਈ ਫਾਇਦੇ ਪ੍ਰਦਾਨ ਕਰਦੀ ਹੈ:
# - ✅ **ਕੋਈ API ਕੁੰਜੀਆਂ ਦਾ ਪ੍ਰਬੰਧਨ ਨਹੀਂ** - Azure ਆਧਾਰਿਤ ਪਹਿਚਾਣ ਪ੍ਰਮਾਣਿਕਤਾ ਵਰਤਦੀ ਹੈ
# - ✅ **ਵਧੀਕ ਸੁਰੱਖਿਆ** - ਕੋਡ ਜਾਂ ਕਨਫਿਗਰੇਸ਼ਨ ਵਿੱਚ ਕੋਈ ਰਾਜ਼ ਸਟੋਰ ਨਹੀਂ ਹੁੰਦੇ
# - ✅ **ਆਪੋ-ਆਪ ਕ੍ਰਿਡੈਂਸ਼ਲ ਰੋਟੇਸ਼ਨ** - Azure ਕ੍ਰਿਡੈਂਸ਼ਲ ਲਾਈਫਸਾਈਕਲ ਨੂੰ ਸੰਭਾਲਦਾ ਹੈ
# - ✅ **ਰੋਲ-ਅਧਾਰਿਤ ਪਹੁੰਚ** - ਸੁਖਮ ਪਹੁੰਚ ਲਈ Azure RBAC ਵਰਤਦਾ ਹੈ
#
# `DefaultAzureCredential` ਆਪਣੇ ਆਪ ਹੀ ਸਭ ਤੋਂ ਵਧੀਆ ਉਪਲਬਧ ਕ੍ਰਿਡੈਂਸ਼ਲ ਸਰੋਤ ਨੂੰ ਵਰਤੇਗਾ:
# 1. ਮੈਨੇਜਡ ਆਈਡੈਂਟਿਟੀ (ਜਦੋਂ Azure ਵਿੱਚ ਚਲਾਇਆ ਜਾਵੇ)
# 2. Azure CLI ਕ੍ਰਿਡੈਂਸ਼ਲ (ਵਿਕਾਸ ਦੌਰਾਨ)
# 3. Visual Studio ਕ੍ਰਿਡੈਂਸ਼ਲ
# 4. ਵਾਤਾਵਰਣ ਵੈਰੀਏਬਲ (ਜੇ ਕਨਫਿਗਰ ਕੀਤੇ ਗਏ)

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.1.0-beta.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.1.0-beta.4</span></li></ul></div></div>

# %% [markdown]
# ਐਜ਼ਰ ਸੇਵਾਵਾਂ ਨਾਲ ਪ੍ਰਮਾਣਿਕਤਾ ਲਈ DefaultAzureCredential ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਐਜ਼ਰ ਆਈਡੈਂਟਿਟੀ ਪੈਕੇਜ ਇੰਸਟਾਲ ਕਰੋ।

# %%
#r "nuget: Azure.Identity, 1.14.2"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.14.2</span></li></ul></div></div>

# %% [markdown]
# ## ਲੋੜੀਂਦੇ ਨੈਮਸਪੇਸ ਇਮਪੋਰਟ ਕਰੋ
#
# Azure AI Agents ਅਤੇ Azure Identity ਲਈ ਲੋੜੀਂਦੇ ਨੈਮਸਪੇਸ ਇਮਪੋਰਟ ਕਰੋ।

# %%
using Azure.AI.Agents.Persistent;
using Azure.Identity;

# %% [markdown]
# ## ਐਜ਼ਰ ਏਆਈ ਏਜੰਟ ਕਲਾਇੰਟ (ਕੀਲੈਸ ਪ੍ਰਮਾਣਿਕਤਾ) ਨੂੰ ਕਨਫਿਗਰ ਕਰੋ
#
# ਕਨਫਿਗਰੇਸ਼ਨ ਵੈਰੀਏਬਲ ਸੈਟ ਕਰੋ ਅਤੇ **ਕੀਲੈਸ ਪ੍ਰਮਾਣਿਕਤਾ** ਦੀ ਵਰਤੋਂ ਕਰਕੇ PersistentAgentsClient ਬਣਾਓ:
# - **projectEndpoint**: ਐਜ਼ਰ ਏਆਈ ਫਾਊਂਡਰੀ ਪ੍ਰੋਜੈਕਟ ਐਂਡਪੌਇੰਟ
# - **modelDeploymentName**: ਤੈਨਾਤ ਕੀਤੇ ਏਆਈ ਮਾਡਲ ਦਾ ਨਾਮ (GPT-4.1 ਨੈਨੋ)
# - **mcpServerUrl**: MCP ਸਰਵਰ ਦਾ URL (ਮਾਈਕਰੋਸਾਫਟ ਲਰਨ API)
# - **mcpServerLabel**: MCP ਸਰਵਰ ਦੀ ਪਛਾਣ ਕਰਨ ਲਈ ਇੱਕ ਲੇਬਲ
# - **DefaultAzureCredential**: ਪ੍ਰਬੰਧਿਤ ਪਹਿਚਾਣ, ਐਜ਼ਰ CLI, ਜਾਂ ਹੋਰ ਪ੍ਰਮਾਣਿਕਤਾ ਸਰੋਤਾਂ ਦੀ ਵਰਤੋਂ ਕਰਦਾ ਹੈ (ਕੋਈ API ਕੁੰਜੀਆਂ ਦੀ ਲੋੜ ਨਹੀਂ)

# %%
var projectEndpoint = "Your Azure AI Foundry Project Endpoint";
var modelDeploymentName = "Your Azure OpenAI Model Deployment Name";
var mcpServerUrl = "https://learn.microsoft.com/api/mcp";
var mcpServerLabel = "mslearn";
PersistentAgentsClient agentClient = new(projectEndpoint, new DefaultAzureCredential());

# %% [markdown]
# ## ਐਮਸੀਪੀ ਟੂਲ ਪਰਿਭਾਸ਼ਾ ਬਣਾਓ
#
# ਐਮਸੀਪੀ ਟੂਲ ਪਰਿਭਾਸ਼ਾ ਬਣਾਓ ਜੋ ਮਾਈਕਰੋਸਾਫਟ ਲਰਨ ਐਮਸੀਪੀ ਸਰਵਰ ਨਾਲ ਜੁੜਦੀ ਹੈ। ਇਹ ਏਜੰਟ ਨੂੰ ਮਾਈਕਰੋਸਾਫਟ ਲਰਨ ਸਮੱਗਰੀ ਅਤੇ ਦਸਤਾਵੇਜ਼ੀਕਰਨ ਤੱਕ ਪਹੁੰਚ ਕਰਨ ਦੀ ਆਗਿਆ ਦੇਵੇਗਾ।

# %%
MCPToolDefinition mcpTool = new(mcpServerLabel, mcpServerUrl);

# %% [markdown]
# ## AI ਏਜੰਟ ਬਣਾਓ
#
# ਦਿੱਤੇ ਗਏ ਮਾਡਲ ਅਤੇ MCP ਟੂਲਾਂ ਨਾਲ ਇੱਕ ਸਥਾਈ AI ਏਜੰਟ ਬਣਾਓ। ਏਜੰਟ ਨੂੰ ਹੇਠਾਂ ਦਿੱਤੇ ਤਰੀਕੇ ਨਾਲ ਕਨਫਿਗਰ ਕੀਤਾ ਗਿਆ ਹੈ:
# - GPT-4.1 ਨੈਨੋ ਮਾਡਲ
# - ਸਹਾਇਤਾ ਲਈ MCP ਟੂਲਾਂ ਦੀ ਵਰਤੋਂ ਕਰਨ ਦੇ ਨਿਰਦੇਸ਼
# - Microsoft Learn MCP ਸਰਵਰ ਤੱਕ ਪਹੁੰਚ

# %%
PersistentAgent agent = await agentClient.Administration.CreateAgentAsync(
   model: modelDeploymentName,
   name: "my-learn-agent",
   instructions: "You are a helpful agent that can use MCP tools to assist users. Use the available MCP tools to answer questions and perform tasks.",
   tools: [mcpTool]
   );

# %% [markdown]
# ## ਥ੍ਰੈਡ ਬਣਾਓ ਅਤੇ ਸੁਨੇਹਾ ਭੇਜੋ
#
# ਗੱਲਬਾਤ ਦਾ ਥ੍ਰੈਡ ਬਣਾਓ ਅਤੇ ਵਰਤੋਂਕਾਰ ਨੂੰ ਸੁਨੇਹਾ ਭੇਜੋ ਜਿਸ ਵਿੱਚ Azure OpenAI ਅਤੇ OpenAI ਦੇ ਫਰਕ ਬਾਰੇ ਪੁੱਛਿਆ ਗਿਆ ਹੋਵੇ। ਇਹ ਏਜੰਟ ਦੀ ਸਮਰੱਥਾ ਦੀ ਜਾਂਚ ਕਰੇਗਾ ਕਿ ਉਹ MCP ਟੂਲਜ਼ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਸਹੀ ਜਾਣਕਾਰੀ ਪ੍ਰਦਾਨ ਕਰ ਸਕਦਾ ਹੈ।

# %%
PersistentAgentThread thread = await agentClient.Threads.CreateThreadAsync();

// Create message to thread
PersistentThreadMessage message = await agentClient.Messages.CreateMessageAsync(
    thread.Id,
    MessageRole.User,
    "What's difference between Azure OpenAI and OpenAI?");

# %% [markdown]
# ## ਐਮਸੀਪੀ ਟੂਲ ਰਿਸੋਰਸਾਂ ਨੂੰ ਕਨਫਿਗਰ ਕਰੋ (ਬਿਨਾ ਕੁੰਜੀ ਦੇ)
#
# ਐਮਸੀਪੀ ਟੂਲ ਰਿਸੋਰਸਾਂ ਨੂੰ ਸੈਟਅੱਪ ਕਰੋ। ਇੱਕ ਸੱਚਮੁੱਚ ਬਿਨਾ ਕੁੰਜੀ ਵਾਲੇ ਤਰੀਕੇ ਲਈ, ਤੁਸੀਂ ਕਸਟਮ ਹੈਡਰ ਹਟਾ ਸਕਦੇ ਹੋ ਜੇਕਰ ਐਮਸੀਪੀ ਸਰਵਰ ਐਜ਼ਰ ਆਈਡੈਂਟਿਟੀ-ਅਧਾਰਿਤ ਪ੍ਰਮਾਣਿਕਤਾ ਦਾ ਸਮਰਥਨ ਕਰਦਾ ਹੈ। ਹੇਠਾਂ ਦਿੱਤੇ ਉਦਾਹਰਨ ਵਿੱਚ ਦਿਖਾਇਆ ਗਿਆ ਹੈ ਕਿ ਜੇ ਲੋੜ ਹੋਵੇ ਤਾਂ ਹੈਡਰ ਕਿਵੇਂ ਸ਼ਾਮਲ ਕੀਤੇ ਜਾਣ, ਪਰ ਬਿਨਾ ਕੁੰਜੀ ਵਾਲੇ ਸਥਿਤੀਆਂ ਵਿੱਚ, ਇਹ ਲੋੜੀਂਦੇ ਨਹੀਂ ਹੋ ਸਕਦੇ।

# %%
// Option 1: Completely keyless (if MCP server supports Azure identity)
MCPToolResource mcpToolResource = new(mcpServerLabel);
ToolResources toolResources = mcpToolResource.ToToolResources();

// Option 2: With custom headers (if still needed for specific MCP servers)
// MCPToolResource mcpToolResource = new(mcpServerLabel);
// mcpToolResource.UpdateHeader("Authorization", "Bearer <your-token>");
// ToolResources toolResources = mcpToolResource.ToToolResources();

# %% [markdown]
# ## ਏਜੰਟ ਰਨ ਸ਼ੁਰੂ ਕਰੋ
#
# ਉਪਭੋਗਤਾ ਦੇ ਸੁਨੇਹੇ ਨੂੰ ਪ੍ਰਕਿਰਿਆ ਕਰਨ ਲਈ ਇੱਕ ਰਨ ਬਣਾਓ ਅਤੇ ਸ਼ੁਰੂ ਕਰੋ। ਏਜੰਟ ਸੰਕਲਿਤ MCP ਟੂਲਾਂ ਅਤੇ ਸਰੋਤਾਂ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਜਵਾਬ ਤਿਆਰ ਕਰੇਗਾ।

# %%
ThreadRun run = await agentClient.Runs.CreateRunAsync(thread, agent, toolResources);

# %% [markdown]
# ## ਰਨ ਦੀ ਨਿਗਰਾਨੀ ਕਰੋ ਅਤੇ ਟੂਲ ਅਨੁਮਤੀਆਂ ਨੂੰ ਸੰਭਾਲੋ (ਕੀਲੈਸ)
#
# ਏਜੰਟ ਰਨ ਦੀ ਸਥਿਤੀ ਦੀ ਨਿਗਰਾਨੀ ਕਰੋ ਅਤੇ ਜਰੂਰੀ ਟੂਲ ਅਨੁਮਤੀਆਂ ਨੂੰ ਸੰਭਾਲੋ। ਇਹ ਲੂਪ:
# 1. ਰਨ ਦੇ ਪੂਰਾ ਹੋਣ ਜਾਂ ਕਾਰਵਾਈ ਦੀ ਲੋੜ ਹੋਣ ਦੀ ਉਡੀਕ ਕਰਦਾ ਹੈ
# 2. ਜਦੋਂ ਲੋੜ ਹੋਵੇ, ਤਾਂ MCP ਟੂਲ ਕਾਲਾਂ ਨੂੰ ਆਟੋਮੈਟਿਕ ਤੌਰ 'ਤੇ ਅਨੁਮਤੀ ਦਿੰਦਾ ਹੈ
# 3. ਕੀਲੈਸ ਪ੍ਰਮਾਣਿਕਤਾ ਲਈ, ਹੈਡਰ ਦੀ ਲੋੜ ਨਹੀਂ ਹੋ ਸਕਦੀ ਜੇ MCP ਸਰਵਰ Azure ਪਛਾਣ ਨੂੰ ਸਹਿਯੋਗ ਦਿੰਦਾ ਹੈ

# %%
while (run.Status == RunStatus.Queued || run.Status == RunStatus.InProgress || run.Status == RunStatus.RequiresAction)
{
    await Task.Delay(TimeSpan.FromMilliseconds(1000));
    run = await agentClient.Runs.GetRunAsync(thread.Id, run.Id);

    if (run.Status == RunStatus.RequiresAction && run.RequiredAction is SubmitToolApprovalAction toolApprovalAction)
    {
        var toolApprovals = new List<ToolApproval>();
        foreach (var toolCall in toolApprovalAction.SubmitToolApproval.ToolCalls)
        {
            if (toolCall is RequiredMcpToolCall mcpToolCall)
            {
                Console.WriteLine($"Approving MCP tool call: {mcpToolCall.Name}");
                
                // Option 1: Keyless approval (no headers needed)
                toolApprovals.Add(new ToolApproval(mcpToolCall.Id, approve: true));
                
                // Option 2: With headers (if required by specific MCP server)
                // toolApprovals.Add(new ToolApproval(mcpToolCall.Id, approve: true)
                // {
                //     Headers = { ["Authorization"] = "Bearer <your-token>" }
                // });
            }
        }

        if (toolApprovals.Count > 0)
        {
            run = await agentClient.Runs.SubmitToolOutputsToRunAsync(thread.Id, run.Id, toolApprovals: toolApprovals);
        }
    }
}
# Out:
# Approving MCP tool call: microsoft_docs_search

# %% [markdown]
# ## ਗੱਲਬਾਤ ਦੇ ਨਤੀਜੇ ਦਿਖਾਓ
#
# ਥ੍ਰੈਡ ਵਿੱਚ ਸਾਰੇ ਸੁਨੇਹੇ ਪ੍ਰਾਪਤ ਕਰੋ ਅਤੇ ਦਿਖਾਓ, ਜਿਸ ਵਿੱਚ ਉਪਭੋਗਤਾ ਦੇ ਪ੍ਰਸ਼ਨ ਅਤੇ ਏਜੰਟ ਦੇ ਜਵਾਬ ਦੋਵੇਂ ਸ਼ਾਮਲ ਹਨ। ਸੁਨੇਹੇ ਸਮਾਂ-ਅਨੁਸਾਰ ਕ੍ਰਮ ਵਿੱਚ ਟਾਈਮਸਟੈਂਪ ਅਤੇ ਭੂਮਿਕਾ ਸੰਕੇਤਕਾਂ ਦੇ ਨਾਲ ਦਿਖਾਏ ਜਾਂਦੇ ਹਨ।

# %%
using Azure;

AsyncPageable<PersistentThreadMessage> messages = agentClient.Messages.GetMessagesAsync(
    threadId: thread.Id,
    order: ListSortOrder.Ascending
);

await foreach (PersistentThreadMessage threadMessage in messages)
{
    Console.Write($"{threadMessage.CreatedAt:yyyy-MM-dd HH:mm:ss} - {threadMessage.Role,10}: ");
    foreach (MessageContent contentItem in threadMessage.ContentItems)
    {
        if (contentItem is MessageTextContent textItem)
        {
            Console.Write(textItem.Text);
        }
        else if (contentItem is MessageImageFileContent imageFileItem)
        {
            Console.Write($"<image from ID: {imageFileItem.FileId}>");
        }
        Console.WriteLine();
    }
}
# Out:
# 2025-07-16 06:39:43 -       user: What's difference between Azure OpenAI and OpenAI?
# 2025-07-16 06:39:51 -  assistant: The main difference between Azure OpenAI and OpenAI lies in their deployment, management, and integration options:
#
# 1. **Azure OpenAI**:
#    - A cloud service offered through Microsoft Azure.
#    - Provides access to OpenAI models with additional enterprise features like security, compliance, and scale.
#    - Allows integration with other Azure services, enabling seamless use within existing Azure-based solutions.
#    - Offers managed deployment, monitoring, and support within the Azure ecosystem.
#    - Suitable for organizations looking for enterprise-grade security, compliance, and regional availability.
#
# 2. **OpenAI (OpenAI API)**:
#    - A standalone API service provided directly by OpenAI.
#    - Accessible via the OpenAI platform without the need for Azure.
# ...

# %% [markdown]
# ---
#
# **ਅਸਵੀਕਰਤੀ**:
# ਇਹ ਦਸਤਾਵੇਜ਼ AI ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਅਨੁਵਾਦ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀ ਹੋਣ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦੇ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਦਿਓ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸੁਣੀਕਤਾਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼, ਜੋ ਇਸਦੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਹੈ, ਨੂੰ ਅਧਿਕਾਰਤ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਇਸ ਅਨੁਵਾਦ ਦੀ ਵਰਤੋਂ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੇ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆ ਲਈ ਅਸੀਂ ਜ਼ਿੰਮੇਵਾਰ ਨਹੀਂ ਹਾਂ।
